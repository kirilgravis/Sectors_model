# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Ideas

# %% [markdown]
# ## From RR

# %% [markdown]
# 1) Fundementals (20%)

# %% [markdown]
# * CPI
# * 1Y
# * 5Y
# * Expected_inflation_5Y

# %% [markdown]
# 2) Valuations (20%)

# %% [markdown]
# *  p/e ratio
# * forward p / e

# %% [markdown]
# 3) Technicals  (20%)

# %% [markdown]
# * Sectors RSI
# * Sectors MA 50 / 200

# %% [markdown]
# 4) Sentiment  (20%)

# %% [markdown]
# * aaii
# * bull-bear spred in aaii
# * naaim
# * median in naaim
# * std in naaim

# %% [markdown]
# 5) Positioning & Fund Flows  (20%)

# %% [markdown]
# * fund flows?
# * global volatility?

# %% [markdown]
# # Analysys

# %%
returns = pd.read_excel(r"data\SP500_Sectors_returns.xls", header=1)
returns.head(5)
# Out:
#        Dates  S&P 500 Real Estate  S&P 500 Communication Services   \
# 0 2023-02-28               140.88                           113.98
# 1 2023-01-31               149.82                           119.57
# 2 2022-12-30               136.34                           104.50
# 3 2022-11-30               143.55                           113.38
# 4 2022-10-31               134.33                           106.12
#
#    S&P 500 Financials   S&P 500 Information Technology  \
# 0               270.12                          618.76
# 1               276.60                          616.29
# 2               258.95                          563.84
# 3               273.41                          615.47
# 4               255.57                          580.80
#
#    S&P 500 Consumer Discretionary   S&P 500 Consumer Staples   \
# 0                          1627.57                     464.51
# 1                          1662.36                     476.06
# ...

# %%
aaii = pd.read_excel(r"data\AAII.xls")
aaii.head(5)
# Out:
#   Reported_Date  Bullish  Neutral  Bearish
# 0    1987-07-24     0.36     0.50     0.14
# 1    1987-07-31     0.26     0.48     0.26
# 2    1987-08-07     0.56     0.15     0.29
# 3    1987-08-14     0.45     0.35     0.20
# 4    1987-08-21     0.66     0.28     0.06

# %%
naaim = pd.read_excel(r"data\naaim.xls")
naaim.head(5)
# Out:
#         Date  Mean/Average  Most Bearish Response  Quart 1 (25% at/below)  \
# 0 2023-03-15         41.92                 -150.0                  0.0000
# 1 2023-03-08         60.11                 -150.0                 40.0000
# 2 2023-03-01         47.41                 -175.0                 23.1250
# 3 2023-02-22         57.09                 -200.0                 45.3125
# 4 2023-02-15         81.43                  -50.0                 65.0000
#
#    Quart 2 (median)  Quart 3 (25% at/above)  Most Bullish Response  \
# 0              55.0                    70.0                  200.0
# 1              60.0                   100.0                  200.0
# 2              50.0                    75.0                  200.0
# 3              66.0                   100.0                  200.0
# 4              75.0                   100.0                  200.0
#
#    Standard Deviation  NAAIM Number  S&P 500
# 0               66.69         41.92  3891.93
# ...

# %%
value = pd.read_csv('data/pe_cpi_Treas.csv')
value
# Out:
#            date  PE_RATIO  Fwd_PE_RATIO  5Y_GENERIC  1Y_GENERIC  S&P_500_TR  \
# 0           NaN       NaN           NaN         NaN         NaN         NaN
# 1    29/07/2022      20.0          17.0         2.7        2.89      8730.0
# 2    30/06/2022      18.0          15.0         3.0        2.74      7993.0
# 3    31/05/2022      21.0          17.0         2.8        2.05      8713.0
# 4    29/04/2022      21.0          17.0         3.0        2.06      8697.0
# ..          ...       ...           ...         ...         ...         ...
# 363  29/05/1992      27.0          14.0         6.6        4.24       484.0
# 364  30/04/1992      26.0          13.0         6.9        4.31       481.0
# 365  31/03/1992      26.0          13.0         6.9        4.49       468.0
# 366  28/02/1992      26.0          13.0         6.6        4.30       477.0
# 367  31/01/1992      26.0          13.0         6.4        4.19       471.0
#
# ...
